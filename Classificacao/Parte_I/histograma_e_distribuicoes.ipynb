# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("./dados/base_prob.csv")

# %%
df
# Out:
#         age  SeriousDlqin2yrs  MonthlyIncome
# 0        45                 1         9120.0
# 1        40                 0         2600.0
# 2        38                 0         3042.0
# 3        30                 0         3300.0
# 4        74                 0         3500.0
# ...     ...               ...            ...
# 119995   59                 0        10316.0
# 119996   22                 0          820.0
# 119997   50                 0         3400.0
# 119998   74                 0         2100.0
# 119999   44                 0         5584.0
#
# [120000 rows x 3 columns]

# %% [markdown]
# ### Histograma da Idade

# %%
plt.hist(df.age)
# Out:
# (array([1.0000e+00, 0.0000e+00, 9.0490e+03, 2.3656e+04, 2.9826e+04,
#         2.7546e+04, 2.0138e+04, 7.6550e+03, 2.0130e+03, 1.1600e+02]),
#  array([  0. ,  10.3,  20.6,  30.9,  41.2,  51.5,  61.8,  72.1,  82.4,
#          92.7, 103. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.figure(figsize=(15,5))
plt.hist(df.age, bins=np.arange(0,101,1), rwidth=.8);

# %%
plt.figure(figsize=(15,5))
plt.hist(df.age, bins=np.arange(0,101,1), rwidth=.8);

plt.xlabel("Idade")
plt.ylabel("Contagem de pessoas")
# Out:
# Text(0, 0.5, 'Contagem de pessoas')

# %%
plt.figure(figsize=(15,5))
plt.hist(df.age, bins=np.arange(0,101,1), rwidth=.8);

plt.xlabel("Idade", fontsize=16)
plt.ylabel("Contagem de pessoas", fontsize=16)
# Out:
# Text(0, 0.5, 'Contagem de pessoas')

# %%
plt.figure(figsize=(15,5))
plt.hist(df.age, bins=np.arange(0,101,1), rwidth=.8);

plt.xlabel("Idade", fontsize=16)
plt.ylabel("Contagem de pessoas", fontsize=16)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
# Out:
# (array([   0.,  500., 1000., 1500., 2000., 2500., 3000., 3500.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
plt.figure(figsize=(15,5))
plt.hist(df.age, bins=np.arange(0,101,1), rwidth=.8);

plt.xlabel("Idade", fontsize=16)
plt.ylabel("Contagem de pessoas", fontsize=16)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.grid()

# %%
plt.figure(figsize=(15,5))
plt.hist(df.age, bins=np.arange(0,101,1), rwidth=.8, density=True);

plt.xlabel("Idade", fontsize=16)
plt.ylabel("Probabilidade por Idade", fontsize=16)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.grid()

# %%
plt.figure(figsize=(15,5))
plt.hist(df.age, bins=np.arange(0,101,1), rwidth=.8, density=True);
plt.axvline(29, color="k")

plt.xlabel("Idade", fontsize=16)
plt.ylabel("Probabilidade por Idade", fontsize=16)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.grid()

# %%
plt.figure(figsize=(15,5))
plt.hist(df.age, bins=np.arange(0,101,1), rwidth=.8, density=True);
plt.axvline(29, color="k")
plt.axhline(0.0125, color="k")

plt.xlabel("Idade", fontsize=16)
plt.ylabel("Probabilidade por Idade", fontsize=16)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.grid()

# %%
plt.figure(figsize=(15,5))
plt.hist(df.age, bins=np.arange(0,101,1), rwidth=.8, density=True);
plt.axvline(29, color="k")
plt.axhline(0.0125, color="k")

plt.xlabel("Idade", fontsize=16)
plt.ylabel("Probabilidade por Idade", fontsize=16)
plt.xticks(fontsize=16)
plt.yticks([0, 0.005, 0.010, 0.0125, 0.015, 0.020, 0.025],fontsize=16)
plt.grid()

# %% [markdown]
# ## Distribuição de probabilidade conjunta

# %%
plt.figure(figsize=(15,5))
#plt.hist(df.age, bins=np.arange(0,101,1), rwidth=.8, density=True);
plt.hist2d(df.age, df.MonthlyIncome, bins=30, density=True)


plt.xlabel("Idade", fontsize=16)
plt.ylabel("Probabilidade por Idade", fontsize=16)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
# Out:
# (array([    0., 10000., 20000., 30000., 40000., 50000., 60000.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
plt.figure(figsize=(15,5))
#plt.hist(df.age, bins=np.arange(0,101,1), rwidth=.8, density=True);
plt.hist2d(df.age, df.MonthlyIncome, bins=30, density=True)
plt.colorbar()

plt.xlabel("Idade", fontsize=16)
plt.ylabel("Probabilidade por Idade", fontsize=16)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
# Out:
# (array([    0., 10000., 20000., 30000., 40000., 50000., 60000.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
plt.figure(figsize=(15,5))

plt.subplot(1,2,1)
plt.hist(df.MonthlyIncome, bins=30, density=True)


plt.subplot(1,2,2)
plt.hist2d(df.age, df.MonthlyIncome, bins=30, density=True)
plt.colorbar()

plt.xlabel("Idade", fontsize=16)
plt.ylabel("Probabilidade por Idade", fontsize=16)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
# Out:
# (array([    0., 10000., 20000., 30000., 40000., 50000., 60000.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
plt.figure(figsize=(15,5))

plt.subplot(1,2,1)
plt.hist(df.MonthlyIncome, bins=30, density=True, orientation="horizontal", rwidth=.8)


plt.subplot(1,2,2)
plt.hist2d(df.age, df.MonthlyIncome, bins=30, density=True)
plt.colorbar()
plt.xlabel("Idade", fontsize=16)
plt.ylabel("Probabilidade por Idade", fontsize=16)
# Out:
# Text(0, 0.5, 'Probabilidade por Idade')

# %%
plt.figure(figsize=(15,5))

plt.subplot(2,2,1)
plt.hist(df.MonthlyIncome, bins=30, density=True, orientation="horizontal", rwidth=.8)

plt.subplot(2,2,2)
plt.hist2d(df.age, df.MonthlyIncome, bins=30, density=True)
plt.colorbar()
plt.xlabel("Idade", fontsize=16)
plt.ylabel("Probabilidade/Idade", fontsize=16)

plt.subplot(2,2,4)
plt.hist(df.age, bins=30, density=True, rwidth=.8)
# Out:
# (array([2.42718447e-06, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 3.94660194e-03, 7.12378641e-03,
#         1.08932039e-02, 1.79611650e-02, 1.48859223e-02, 2.45703883e-02,
#         1.98495146e-02, 2.99878641e-02, 2.25558252e-02, 2.13713592e-02,
#         2.66262136e-02, 1.88616505e-02, 2.35291262e-02, 1.28713592e-02,
#         1.24781553e-02, 7.29611650e-03, 5.73058252e-03, 5.55339806e-03,
#         2.25000000e-03, 2.02427184e-03, 6.11650485e-04, 2.28155340e-04,
#         3.88349515e-05, 1.45631068e-05]),
#  array([  0.        ,   3.43333333,   6.86666667,  10.3       ,
#          13.73333333,  17.16666667,  20.6       ,  24.03333333,
#          27.46666667,  30.9       ,  34.33333333,  37.76666667,
#          41.2       ,  44.63333333,  48.06666667,  51.5       ,
#          54.93333333,  58.36666667,  61.8       ,  65.23333333,
#          68.66666667,  72.1       ,  75.53333333,  78.96666667,
#          82.4       ,  85.83333333,  89.26666667,  92.7       ,
#          96.13333333,  99.56666667, 103.        ]),
#  <BarContainer object of 30 artists>)

# %%
plt.figure(figsize=(15,2*5))

plt.subplot(2,2,1)
plt.hist(df.MonthlyIncome, bins=30, density=True, orientation="horizontal", rwidth=.8)

plt.subplot(2,2,2)
plt.hist2d(df.age, df.MonthlyIncome, bins=30, density=True)
plt.colorbar()
plt.xlabel("Idade", fontsize=16)
plt.ylabel("Probabilidade/Idade", fontsize=16)

plt.subplot(2,2,4)
plt.hist(df.age, bins=30, density=True, rwidth=.8)
# Out:
# (array([2.42718447e-06, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 3.94660194e-03, 7.12378641e-03,
#         1.08932039e-02, 1.79611650e-02, 1.48859223e-02, 2.45703883e-02,
#         1.98495146e-02, 2.99878641e-02, 2.25558252e-02, 2.13713592e-02,
#         2.66262136e-02, 1.88616505e-02, 2.35291262e-02, 1.28713592e-02,
#         1.24781553e-02, 7.29611650e-03, 5.73058252e-03, 5.55339806e-03,
#         2.25000000e-03, 2.02427184e-03, 6.11650485e-04, 2.28155340e-04,
#         3.88349515e-05, 1.45631068e-05]),
#  array([  0.        ,   3.43333333,   6.86666667,  10.3       ,
#          13.73333333,  17.16666667,  20.6       ,  24.03333333,
#          27.46666667,  30.9       ,  34.33333333,  37.76666667,
#          41.2       ,  44.63333333,  48.06666667,  51.5       ,
#          54.93333333,  58.36666667,  61.8       ,  65.23333333,
#          68.66666667,  72.1       ,  75.53333333,  78.96666667,
#          82.4       ,  85.83333333,  89.26666667,  92.7       ,
#          96.13333333,  99.56666667, 103.        ]),
#  <BarContainer object of 30 artists>)
