# %% [markdown]
# - Regressão Logística volta uma probabilidade real, sem necessidade de calibração
# - Permite uma interpretabilidade absoluta das variáveis
# - Implantação rápida e fácil (uma única equação)
# - Tem por, padrão, um viés linear
# - Cuidado com a correlação! Os betas das variáveis podem se cancelar
# - E o impacto dos Betas é este:
#     - Os Betas que multiplicam nas variáveis, vão deixar a reta mais ou menos inclinada naquela variável
#     - Beta_0 (intercepto) vai deslocar a curva
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## O que significa "interpretar" um modelo?
#
# Alguns modelos de negócio precisam conseguir explicar o porque de determinado resultado/ação.
# Exemplo: "Por que meu crédito foi negado? O que eu tenho de diferente de fulano?"
#
# Interpretar é saber o quanto **cada variável** impactou para se chegar a um determinado score.
#
# A única coisa que o modelo ajusta são os betas!
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### E se as variáveis fossem contínuas?
#
# Escalar as variáveis: média e desvio padrão
#
# ## Em resumo:
#
# - Cuidado com as correlações!
# - Pode ser necessário discretizar tudo
# - Os betas fazem sentido? Eles ordenam?
